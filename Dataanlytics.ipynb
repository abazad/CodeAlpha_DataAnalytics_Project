# %% [markdown]
# You can install Python libraries using `pip` by running commands directly in a code cell. Prefix the `pip` command with an exclamation mark `!` to execute it as a shell command.

# %%
# Example: Install the pandas library
# !pip install pandas

# %% [markdown]
# After installation, you can then `import` the library in your Python code.

# %%
# Example: Import the pandas library
import pandas as pd

print("Pandas installed and imported successfully!")

# %%
# !pip install requests beautifulsoup4 pandas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "http://books.toscrape.com/"
response = requests.get(url)

print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

print(soup.title.text)
# Out:
#     All products | Books to Scrape - Sandbox

# %%
books = soup.find_all("article", class_="product_pod")

data = []

for book in books:
    title = book.h3.a["title"]
    price = book.find("p", class_="price_color").text
    rating = book.p["class"][1]

    data.append([title, price, rating])

print(data[:5])
# Out:
# [['A Light in the Attic', 'Â£51.77', 'Three'], ['Tipping the Velvet', 'Â£53.74', 'One'], ['Soumission', 'Â£50.10', 'One'], ['Sharp Objects', 'Â£47.82', 'Four'], ['Sapiens: A Brief History of Humankind', 'Â£54.23', 'Five']]

# %%
data = []

for page in range(1, 6):
    url = f"http://books.toscrape.com/catalogue/page-{page}.html"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    books = soup.find_all("article", class_="product_pod")

    for book in books:
        title = book.h3.a["title"]
        price = book.find("p", class_="price_color").text
        rating = book.p["class"][1]

        data.append([title, price, rating])

# %%
df = pd.DataFrame(data, columns=["Title", "Price", "Rating"])

df["Price"] = df["Price"].str.extract('(\d+\.\d+)').astype(float)


df.head()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_731/2170455354.py:3: SyntaxWarning: invalid escape sequence '\d'
#   df["Price"] = df["Price"].str.extract('(\d+\.\d+)').astype(float)
#                                    Title  Price Rating
# 0                   A Light in the Attic  51.77  Three
# 1                     Tipping the Velvet  53.74    One
# 2                             Soumission  50.10    One
# 3                          Sharp Objects  47.82   Four
# 4  Sapiens: A Brief History of Humankind  54.23   Five

# %%
print(df.shape)
print(df.head())
# Out:
# (100, 3)
#                                    Title  Price Rating
# 0                   A Light in the Attic  51.77  Three
# 1                     Tipping the Velvet  53.74    One
# 2                             Soumission  50.10    One
# 3                          Sharp Objects  47.82   Four
# 4  Sapiens: A Brief History of Humankind  54.23   Five

# %%
from google.colab import files
df.to_csv('Dataanlytics.csv', index=False)
files.download("Dataanlytics.csv")
